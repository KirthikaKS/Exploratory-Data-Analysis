# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\KIRTHIKA K S\\Downloads\\flights.csv")

# %%
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    object
#  2   passengers  144 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.5+ KB

# %%
counts_month = df["month"].value_counts()
print(counts_month)
# Out:
# January      12
# February     12
# March        12
# April        12
# May          12
# June         12
# July         12
# August       12
# September    12
# October      12
# November     12
# December     12
# Name: month, dtype: int64

# %%
grouped_year = df.groupby("year")["passengers"].sum()
print(grouped_year)
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# Name: passengers, dtype: int64

# %%
grouped_month = df.groupby("month")["passengers"].mean()
print(grouped_month)
# Out:
# month
# April        267.083333
# August       351.083333
# December     261.833333
# February     235.000000
# January      241.750000
# July         351.333333
# June         311.666667
# March        270.166667
# May          271.833333
# November     232.833333
# October      266.583333
# September    302.416667
# Name: passengers, dtype: float64

# %%
counts_year = df["year"].value_counts()
print(counts_year)
# Out:
# 1949    12
# 1950    12
# 1951    12
# 1952    12
# 1953    12
# 1954    12
# 1955    12
# 1956    12
# 1957    12
# 1958    12
# 1959    12
# 1960    12
# Name: year, dtype: int64

# %%
df.isna().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.set(style = "whitegrid")
sns.boxplot(x="year", y="passengers", data = df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
monthly_passenger = df.pivot_table(values = "passengers", index = "month", columns = "year")
sns.heatmap(monthly_passenger)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.lineplot(x="year",y="passengers",data = df.groupby("year").sum())
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(x="month",y="passengers",data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
sns.violinplot(x="month",y="passengers",data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
sns.lineplot(x="month",y="passengers",hue="year",data = df.groupby(["year","month"]).mean())
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
sns.histplot(data = df, x="passengers",bins = 10)
# Out:
# <AxesSubplot:xlabel='passengers', ylabel='Count'>

# %%
sns.lineplot(x= df.index , y = "passengers", data = df)
# Out:
# <AxesSubplot:ylabel='passengers'>
